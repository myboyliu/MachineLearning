# %% [markdown]
# #1 特征提取
# 机器学习的过程包括两大部分
# - 特征提取:包括预处理、特征提取方法、维数约简、混合异构特征
# - 机器学习:包括分类器、回归器、聚类器，强化学习
#
# 特征提取将输入空间整理到特征空间上

# %% [markdown]
# #2 混淆矩阵
# 混淆矩阵(confusion matrix)，也被称为错误矩阵，是一个特别的表，用来可视化监督学习算法的性能。在无监督学习中，通常被称为匹配矩阵(matching matrix)。矩阵的每一列表达了分类器对样本的类别预测，而矩阵的每一行则表达了样本所属的真是类别。
#
# 例子：我们的分类器要分类：猫、狗和兔子。假设有27个动物样本：8猫、6狗、13兔子。混淆矩阵如下：![images](images/01/05.png)
